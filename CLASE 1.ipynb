# %% [markdown]
# #CLASE1

# %%
#tipos de variables
A = "carlos" #variable de tipo cade de texto
carlos = 12 #variable de tipo entero
stra = 1.79
deporte = False

# %%
#funcion type() - investigar el tipo de datos que tiene una variable
type(A)
# Out:
# str

# %%
type(carlos)
# Out:
# int

# %%
type(stra)
# Out:
# float
