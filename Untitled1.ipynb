# %%
A = 5
a = "cinco"
b = True
c = 17,3

# %% [markdown]
# TUPLA

# %%
b = (2, 3, 7) #inmutable, no cambian

# %% [markdown]
# LISTA

# %%
D = ["juan", "carlos"] #es modificable

# %%
print ("la variable:", type (543))
print ("la variable:", type (16.84))
print ("la variable:", type ("hola"))
print ("la variable:", type (True))
# Out:
# la variable: <class 'int'>
# la variable: <class 'float'>
# la variable: <class 'str'>
# la variable: <class 'bool'>

# %% [markdown]
# VARIABLES QUE ALMACENAN MULTIPLES

# %%
#declaracion o creacion de una tupla
# Out:
#   File "<ipython-input-20-1c07f4dac27b>", line 4
#     print ("la variable es de tipo: ", type (No_modificable)
#                                                             ^
# SyntaxError: incomplete input
